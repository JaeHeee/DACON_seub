# %% [markdown]
# ## Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Data

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
submission = pd.read_csv('./submission.csv')

# %% [markdown]
# ## EDA

# %%
train
# Out:
#         id  digit letter  0  1  2  3  4  5  6  ...  774  775  776  777  778  \
# 0        1      5      L  1  1  1  4  3  0  0  ...    2    1    0    1    2
# 1        2      0      B  0  4  0  0  4  1  1  ...    0    3    0    1    4
# 2        3      4      L  1  1  2  2  1  1  1  ...    3    3    3    0    2
# 3        4      9      D  1  2  0  2  0  4  0  ...    3    3    2    0    1
# 4        5      6      A  3  0  2  4  0  3  0  ...    4    4    3    2    1
# ...    ...    ...    ... .. .. .. .. .. .. ..  ...  ...  ...  ...  ...  ...
# 2043  2044      6      V  2  4  3  4  2  4  4  ...    0    2    2    0    0
# 2044  2045      1      L  3  2  2  1  1  4  0  ...    2    3    4    2    1
# 2045  2046      9      A  4  0  4  0  2  4  4  ...    2    3    1    1    3
# 2046  2047      0      Z  2  3  3  0  3  0  4  ...    2    3    1    1    0
# 2047  2048      5      Z  4  2  2  1  3  0  0  ...    4    2    4    0    4
#
#       779  780  781  782  783
# ...

# %%
test
# Out:
#           id letter  0  1  2  3  4  5  6  7  ...  774  775  776  777  778  \
# 0       2049      L  0  4  0  2  4  2  3  1  ...    2    0    4    2    2
# 1       2050      C  4  1  4  0  1  1  0  2  ...    0    3    2    4    2
# 2       2051      S  0  4  0  1  3  2  3  0  ...    1    3    2    0    3
# 3       2052      K  2  1  3  3  3  4  3  0  ...    3    0    3    2    4
# 4       2053      W  1  0  1  1  2  2  1  4  ...    4    3    1    4    0
# ...      ...    ... .. .. .. .. .. .. .. ..  ...  ...  ...  ...  ...  ...
# 20475  22524      P  1  2  1  1  0  0  0  2  ...    0    1    3    0    3
# 20476  22525      S  4  1  1  4  0  0  1  1  ...    1    3    1    0    0
# 20477  22526      B  4  2  1  3  2  1  3  0  ...    3    2    3    4    1
# 20478  22527      K  1  1  2  3  4  0  4  3  ...    2    0    0    4    3
# 20479  22528      S  2  1  0  3  0  3  3  1  ...    0    3    0    1    4
#
#        779  780  781  782  783
# 0        4    3    4    1    4
# ...

# %% [markdown]
# ## Dataset

# %%
X_train = np.array(train[[str(i) for i in range(784)]])
X_test = np.array(test[[str(i) for i in range(784)]])

# %%
X_train = X_train.reshape(-1,1,28,28)

# %%
X_train.shape
# Out:
# (2048, 1, 28, 28)

# %%
plt.show(X_train[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-8210e8515b31> in <module>
# ----> 1 plt.show(X_train[0])
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
X_test = X_test.reshape(-1,1,28,28)

# %%
X_test.shape
# Out:
# (20480, 810)

# %%
y_train = train['digit'].values

# %%
y_train
# Out:
# array([5, 0, 4, ..., 9, 0, 5])

# %%
y_train.shape
# Out:
# (2048,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
X_test = pd.concat((pd.get_dummies(test.letter), test[[str(i) for i in range(784)]]), axis=1)

submission.digit = lgb.predict(X_test)

submission.to_csv('first_submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6de11e707d3d> in <module>
#       1 X_test = pd.concat((pd.get_dummies(test.letter), test[[str(i) for i in range(784)]]), axis=1)
#       2
# ----> 3 submission.digit = lgb.predict(X_test)
#       4
#       5 submission.to_csv('first_submission.csv', index=False)
#
# NameError: name 'lgb' is not defined
